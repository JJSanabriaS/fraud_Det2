# %% [markdown]
# <a href="https://colab.research.google.com/github/JJSanabriaS/fraud_Det2/blob/main/proto2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pdfreader

# %%
from pdfreader import PDFDocument, SimplePDFViewer
import timeit

start = timeit.timeit()

# get raw document
fd = open('drive/MyDrive/jonasmotta/test3.pdf', "rb")
doc = PDFDocument(fd)

# there is an iterator for pages
page_one = next(doc.pages())
all_pages = [p for p in doc.pages()]

# and even a viewer
fd = open('drive/MyDrive/jonasmotta/test3.pdf', "rb")
viewer = SimplePDFViewer(fd)

print(all_pages)
end = timeit.timeit()
print(end - start)
# Out:
# [{'Parent': <IndirectReference:n=32,g=0>, 'Type': 'Page', 'Contents': <IndirectReference:n=33,g=0>, 'Resources': {'ProcSet': ['PDF', 'Text', 'ImageB', 'ImageC', 'ImageI'], 'XObject': {'img1': <IndirectReference:n=34,g=0>, 'img0': <IndirectReference:n=35,g=0>}, 'Font': {'F1': <IndirectReference:n=36,g=0>, 'F2': <IndirectReference:n=37,g=0>}}, 'MediaBox': [0, 0, 595, 842]}, {'Parent': <IndirectReference:n=32,g=0>, 'Type': 'Page', 'Contents': <IndirectReference:n=38,g=0>, 'Resources': {'ProcSet': ['PDF', 'Text', 'ImageB', 'ImageC', 'ImageI'], 'Font': {'F1': <IndirectReference:n=36,g=0>, 'F2': <IndirectReference:n=37,g=0>, 'F3': <IndirectReference:n=39,g=0>}}, 'MediaBox': [0, 0, 595, 842]}, {'Group': {'Type': 'Group', 'CS': 'DeviceRGB', 'S': 'Transparency'}, 'Parent': <IndirectReference:n=32,g=0>, 'Contents': <IndirectReference:n=40,g=0>, 'Type': 'Page', 'Resources': <IndirectReference:n=41,g=0>, 'MediaBox': [0, 0, Decimal('595.276'), Decimal('841.89')]}, {'Parent': <IndirectReference:n=32,g=0>, 'Type': 'Page', 'Contents': <IndirectReference:n=56,g=0>, 'Resources': {'ProcSet': ['PDF', 'Text', 'ImageB', 'ImageC', 'ImageI'], 'XObject': {'img1': <IndirectReference:n=57,g=0>, 'img0': <IndirectReference:n=58,g=0>}, 'Font': {'F1': <IndirectReference:n=59,g=0>, 'F2': <IndirectReference:n=60,g=0>}}, 'MediaBox': [0, 0, 595, 842]}, {'Parent': <IndirectReference:n=32,g=0>, 'Type': 'Page', 'Contents': <IndirectReference:n=61,g=0>, 'Resources': {'ProcSet': ['PDF', 'Text', 'ImageB', 'ImageC', 'ImageI'], 'Font': {'F1': <IndirectReference:n=62,g=0>, 'F2': <IndirectReference:n=63,g=0>}}, 'MediaBox': [0, 0, 595, 842]}, {'Group': {'Type': 'Group', 'CS': 'DeviceRGB', 'S': 'Transparency'}, 'Parent': <IndirectReference:n=32,g=0>, 'Contents': <IndirectReference:n=64,g=0>, 'Type': 'Page', 'Tabs': 'S', 'Resources': {'ExtGState': {'GS8': <IndirectReference:n=65,g=0>, 'GS7': <IndirectReference:n=66,g=0>}, 'ProcSet': ['PDF', 'Text', 'ImageB', 'ImageC', 'ImageI'], 'XObject': {'Image16': <IndirectReference:n=67,g=0>}, 'Font': {'F1': <IndirectReference:n=69,g=0>, 'F2': <IndirectReference:n=73,g=0>, 'F3': <IndirectReference:n=80,g=0>, 'F4': <IndirectReference:n=83,g=0>}}, 'MediaBox': [0, 0, Decimal('595.32'), Decimal('841.92')], 'StructParents': 2, 'Annots': [<IndirectReference:n=87,g=0>, <IndirectReference:n=88,g=0>, <IndirectReference:n=89,g=0>, <IndirectReference:n=90,g=0>, <IndirectReference:n=91,g=0>, <IndirectReference:n=92,g=0>, <IndirectReference:n=93,g=0>, <IndirectReference:n=94,g=0>, <IndirectReference:n=95,g=0>, <IndirectReference:n=96,g=0>, <IndirectReference:n=97,g=0>, <IndirectReference:n=98,g=0>, <IndirectReference:n=99,g=0>, <IndirectReference:n=100,g=0>, <IndirectReference:n=101,g=0>, <IndirectReference:n=102,g=0>, <IndirectReference:n=103,g=0>, <IndirectReference:n=104,g=0>, <IndirectReference:n=105,g=0>, <IndirectReference:n=106,g=0>, <IndirectReference:n=107,g=0>, <IndirectReference:n=108,g=0>, <IndirectReference:n=109,g=0>, <IndirectReference:n=110,g=0>, <IndirectReference:n=111,g=0>]}, {'Group': {'Type': 'Group', 'CS': 'DeviceRGB', 'S': 'Transparency'}, 'Parent': <IndirectReference:n=32,g=0>, 'Contents': <IndirectReference:n=112,g=0>, 'Type': 'Page', 'Tabs': 'S', 'Resources': {'ExtGState': {'GS8': <IndirectReference:n=65,g=0>, 'GS7': <IndirectReference:n=66,g=0>}, 'ProcSet': ['PDF', 'Text', 'ImageB', 'ImageC', 'ImageI'], 'XObject': {'Image70': <IndirectReference:n=113,g=0>}, 'Font': {'F1': <IndirectReference:n=69,g=0>, 'F2': <IndirectReference:n=73,g=0>, 'F3': <IndirectReference:n=80,g=0>, 'F4': <IndirectReference:n=83,g=0>}}, 'MediaBox': [0, 0, Decimal('595.32'), Decimal('841.92')], 'StructParents': 26}, {'Group': {'Type': 'Group', 'CS': 'DeviceRGB', 'S': 'Transparency'}, 'Parent': <IndirectReference:n=32,g=0>, 'Contents': <IndirectReference:n=115,g=0>, 'Type': 'Page', 'Tabs': 'S', 'Resources': {'ExtGState': {'GS8': <IndirectReference:n=65,g=0>, 'GS7': <IndirectReference:n=66,g=0>}, 'ProcSet': ['PDF', 'Text', 'ImageB', 'ImageC', 'ImageI'] ...
# -0.0014554299999645082
